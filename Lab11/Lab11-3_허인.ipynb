# %%
import torch
import torch.optim as optim
import numpy as np

# %%
torch.manual_seed(0)

# %%
sentence = ("if you want to build a ship, don't drum up people together to "
            "collect wood and don't assign them tasks and work, but rather "
            "If we lay, let the day just pass us by I might get to too much talking.")

# %%
# dictionary
char_set = list(set(sentence))
char_dic = {c: i for i, c in enumerate(char_set)}

# %%
# hyper parameters
dic_size = len(char_dic)
hidden_size = len(char_dic)
sequence_length = 10  # Any arbitrary number
learning_rate = 0.1

# %%
# data setting
x_data = []
y_data = []

for i in range(0, len(sentence) - sequence_length):
    x_str = sentence[i:i + sequence_length]
    y_str = sentence[i + 1: i + sequence_length + 1]
    print(i, x_str, '->', y_str)

    x_data.append([char_dic[c] for c in x_str])  # x str to index
    y_data.append([char_dic[c] for c in y_str])  # y str to index

x_one_hot = [np.eye(dic_size)[x] for x in x_data]
# Out:
# 0 if you wan -> f you want
# 1 f you want ->  you want
# 2  you want  -> you want t
# 3 you want t -> ou want to
# 4 ou want to -> u want to
# 5 u want to  ->  want to b
# 6  want to b -> want to bu
# 7 want to bu -> ant to bui
# 8 ant to bui -> nt to buil
# 9 nt to buil -> t to build
# 10 t to build ->  to build
# 11  to build  -> to build a
# 12 to build a -> o build a
# 13 o build a  ->  build a s
# 14  build a s -> build a sh
# 15 build a sh -> uild a shi
# 16 uild a shi -> ild a ship
# 17 ild a ship -> ld a ship,
# 18 ld a ship, -> d a ship,
# 19 d a ship,  ->  a ship, d
# 20  a ship, d -> a ship, do
# 21 a ship, do ->  ship, don
# 22  ship, don -> ship, don'
# 23 ship, don' -> hip, don't
# 24 hip, don't -> ip, don't
# 25 ip, don't  -> p, don't d
# 26 p, don't d -> , don't dr
# 27 , don't dr ->  don't dru
# 28  don't dru -> don't drum
# 29 don't drum -> on't drum
# 30 on't drum  -> n't drum u
# 31 n't drum u -> 't drum up
# 32 't drum up -> t drum up
# 33 t drum up  ->  drum up p
# 34  drum up p -> drum up pe
# 35 drum up pe -> rum up peo
# 36 rum up peo -> um up peop
# 37 um up peop -> m up peopl
# 38 m up peopl ->  up people
# 39  up people -> up people
# 40 up people  -> p people t
# 41 p people t ->  people to
# 42  people to -> people tog
# 43 people tog -> eople toge
# 44 eople toge -> ople toget
# 45 ople toget -> ple togeth
# 46 ple togeth -> le togethe
# 47 le togethe -> e together
# 48 e together ->  together
# 49  together  -> together t
# 50 together t -> ogether to
# 51 ogether to -> gether to
# 52 gether to  -> ether to c
# 53 ether to c -> ther to co
# 54 ther to co -> her to col
# 55 her to col -> er to coll
# 56 er to coll -> r to colle
# 57 r to colle ->  to collec
# 58  to collec -> to collect
# 59 to collect -> o collect
# 60 o collect  ->  collect w
# 61  collect w -> collect wo
# 62 collect wo -> ollect woo
# 63 ollect woo -> llect wood
# 64 llect wood -> lect wood
# 65 lect wood  -> ect wood a
# 66 ect wood a -> ct wood an
# 67 ct wood an -> t wood and
# 68 t wood and ->  wood and
# 69  wood and  -> wood and d
# 70 wood and d -> ood and do
# 71 ood and do -> od and don
# 72 od and don -> d and don'
# 73 d and don' ->  and don't
# 74  and don't -> and don't
# 75 and don't  -> nd don't a
# 76 nd don't a -> d don't as
# 77 d don't as ->  don't ass
# 78  don't ass -> don't assi
# 79 don't assi -> on't assig
# 80 on't assig -> n't assign
# 81 n't assign -> 't assign
# 82 't assign  -> t assign t
# 83 t assign t ->  assign th
# 84  assign th -> assign the
# 85 assign the -> ssign them
# 86 ssign them -> sign them
# 87 sign them  -> ign them t
# 88 ign them t -> gn them ta
# 89 gn them ta -> n them tas
# 90 n them tas ->  them task
# 91  them task -> them tasks
# 92 them tasks -> hem tasks
# 93 hem tasks  -> em tasks a
# 94 em tasks a -> m tasks an
# 95 m tasks an ->  tasks and
# 96  tasks and -> tasks and
# 97 tasks and  -> asks and w
# 98 asks and w -> sks and wo
# 99 sks and wo -> ks and wor
# 100 ks and wor -> s and work
# 101 s and work ->  and work,
# 102  and work, -> and work,
# 103 and work,  -> nd work, b
# 104 nd work, b -> d work, bu
# 105 d work, bu ->  work, but
# 106  work, but -> work, but
# 107 work, but  -> ork, but r
# 108 ork, but r -> rk, but ra
# 109 rk, but ra -> k, but rat
# 110 k, but rat -> , but rath
# 111 , but rath ->  but rathe
# 112  but rathe -> but rather
# 113 but rather -> ut rather
# 114 ut rather  -> t rather I
# 115 t rather I ->  rather If
# 116  rather If -> rather If
# 117 rather If  -> ather If w
# 118 ather If w -> ther If we
# 119 ther If we -> her If we
# 120 her If we  -> er If we l
# 121 er If we l -> r If we la
# 122 r If we la ->  If we lay
# 123  If we lay -> If we lay,
# 124 If we lay, -> f we lay,
# 125 f we lay,  ->  we lay, l
# 126  we lay, l -> we lay, le
# 127 we lay, le -> e lay, let
# 128 e lay, let ->  lay, let
# 129  lay, let  -> lay, let t
# 130 lay, let t -> ay, let th
# 131 ay, let th -> y, let the
# 132 y, let the -> , let the
# 133 , let the  ->  let the d
# 134  let the d -> let the da
# 135 let the da -> et the day
# 136 et the day -> t the day
# 137 t the day  ->  the day j
# 138  the day j -> the day ju
# 139 the day ju -> he day jus
# 140 he day jus -> e day just
# 141 e day just ->  day just
# 142  day just  -> day just p
# 143 day just p -> ay just pa
# 144 ay just pa -> y just pas
# 145 y just pas ->  just pass
# 146  just pass -> just pass
# 147 just pass  -> ust pass u
# 148 ust pass u -> st pass us
# 149 st pass us -> t pass us
# 150 t pass us  ->  pass us b
# 151  pass us b -> pass us by
# 152 pass us by -> ass us by
# 153 ass us by  -> ss us by I
# 154 ss us by I -> s us by I
# 155 s us by I  ->  us by I m
# 156  us by I m -> us by I mi
# 157 us by I mi -> s by I mig
# 158 s by I mig ->  by I migh
# 159  by I migh -> by I might
# 160 by I might -> y I might
# 161 y I might  ->  I might g
# 162  I might g -> I might ge
# 163 I might ge ->  might get
# 164  might get -> might get
# 165 might get  -> ight get t
# 166 ight get t -> ght get to
# 167 ght get to -> ht get to
# 168 ht get to  -> t get to t
# 169 t get to t ->  get to to
# 170  get to to -> get to too
# 171 get to too -> et to too
# 172 et to too  -> t to too m
# 173 t to too m ->  to too mu
# 174  to too mu -> to too muc
# 175 to too muc -> o too much
# 176 o too much ->  too much
# 177  too much  -> too much t
# 178 too much t -> oo much ta
# 179 oo much ta -> o much tal
# 180 o much tal ->  much talk
# 181  much talk -> much talki
# 182 much talki -> uch talkin
# 183 uch talkin -> ch talking
# 184 ch talking -> h talking.

# %%
# transform as torch tensor variable
X = torch.FloatTensor(x_one_hot)
Y = torch.LongTensor(y_data)

# %%
class Net(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, layers):
        super(Net, self).__init__()
        self.rnn = torch.nn.RNN(input_dim, hidden_dim, num_layers=layers, batch_first=True)
        self.fc = torch.nn.Linear(hidden_dim, hidden_dim, bias=True)

    def forward(self, x):
        x, _status = self.rnn(x)
        x = self.fc(x)
        return x

net = Net(dic_size, hidden_size, 2)

# %%
# loss & optimizer setting
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), learning_rate)

# %%
# start training
for i in range(100):
    optimizer.zero_grad()
    outputs = net(X)
    loss = criterion(outputs.view(-1, dic_size), Y.view(-1))
    loss.backward()
    optimizer.step()

    results = outputs.argmax(dim=2)
    predict_str = ""
    for j, result in enumerate(results):
        # print(i, j, ''.join([char_set[t] for t in result]), loss.item())
        if j == 0:
            predict_str += ''.join([char_set[t] for t in result])
        else:
            predict_str += char_set[result[-1]]

    print(predict_str)
# Out:
# hhhiihhicifhiiiiihth.bi.thsihiihhfh.c.iiisisiiiiiiiisiiiiiiiiiii.tiifhiiiii.ihihihhfhsh.hthhitiiiishsthsihihiisihhihihsitiiiiiiiiiiiiih.iihiiiiisiiiihthsc.hh.hhhiiiiihtiiiiiihiiiiiiiihiicihiiifs
#
# oatttttottta att  ataetoataotoaotoattt ttttaaattaatta  tt atatttattattattttaattoattoae   aattat t ttttaeattoatttae  ttaottaet attattattta toatttatte otea  ta  tt atta aa ttt ttatta ttatta tt  at
#  k.  .o k..,...oof.oj..of.,..i,j....oi..o.....j..jo,,j.,i.j.o...j.oj.....o,....o...o..oi.. j.oj....ojo......,j.i...o..,..o.j.o..,jj,o..oo..ofj.oo........j.o....i j..of.,.j.oj.o.j.o..oj........j.
#  t  lnso llhlllllllltllllllhlhlhsllllhsll l slslhllllsllhlhslt llslhllhsllllsllhllslllslssl sllsllsl llsshlslsllllsltll llllsll llsllllllllhllslhsl lllhl lllssllltslhsllllhlhlll sltslhllhlllrlls
#                                     t  t    t                 n        t                          t    n               h                                            t
#      tu          us   s  tu  msuy sh  y y  s   u    u  u  us u   ty   s    s    s y uu      s y  y s   t  u y s  u    s     s u   ty yus    s  u tu     s   u   s us      u   us  y s      y u  us
# ds at dos y ss t dey st  oth us dhdu    s st  tw  u o     ag uo oos  doss  g utosodhdo  dssog s  s s sto  dosow dut  us d  og dos os  do  tossdot dos  eut  d   u dwt  st dos dosog   s s og d  ag
# do     ot  ak  t  at dd   t  ut d dot   t dot  d          at  o  at  dot   o , ot d do   o  t   go     ot dot d  a   ot    at  at ao   oo  ots    do    ao  do  o dtt  o   o   o  t  ar , ot dot k
# dot s wey   os t  ay ot   t  os t wos   t at   a          ey to  es  tos  an  tos t to   os h    t  teto  t s   aa  wes    bn  es ts  we  wos  os wos  en   a   a tos  es aos aos o   e    o os ts
# dotos  ehdotos t  aosos   t eos   tob   o es  ges   s     to    ter  es   to  t s   es  oo e s  p s   wo  oey e eo  wes    go wey en  eas wos  gs t s  wo   eo  t e b to  ts  ets    go   g  os t
# gowot wen  w s u  wotoe t e tos   wubo pogee    s  t      eo to won  ee   wo  wos   ts   ost w  tos t wot tos   te  wes   geo wes on  eas wos  os t s  go    o  a   bhwo  te  tusb w b        e eh
# dodo  den  to pa  e d t  pe t  tt do   pn te   e t     t  eot    e   eo   ee  do tt po  te pol  pot   de  des t po  des    po de tan  te  d t dee do   eo   to pa t lolo  te  to to   o   t te  ee
# dote  dont la ta ta eot  ta to tt to   tn ta  ae  t t  a  a  t  te   tae  lo  do    bo tdo a t  po tt do tte  t be  ton  t p  de tent lan tol  an do   ba   de ta bo tuo  te  dote  tlo  tte tn an
# loto  dan  ta ta  e ent  te do  t do   te ta  ae t t   tn bo to te   tan  tot don t te  do to   an    don don t be  ton    an don tn  la  dot dan do   bo   tn le ltt do  do  dotto  lo  dao tn an
# lodo  dan  bu  t  aoent  ae to  t tot  ta mtn  tot     l  aont   en  tot  bot tot t tot dotttu  to t  tot ton t tu  ton    an tetttn  tas tos dun tat  ba   tat u tetodo  tot dottt  to  dao t das
# loto  gun  to lu  a eod  ly to tt tot  ly lan  ent     ln lostos e   tott tos wottt bn  go lhe  los   tot wot   bu  tos  t ly to lan  lu  tos dun to   bo   ty lu totodo  tot totl l to   to t les
# u wo ttost wo bu le bns  lo wostt bu t ln lu  le to t  ls lostotle   gosl tos wostt ln  go lhe  lostt wo twosle bu  tos    ly wuslant tos t e gus wos  wo   ty bu bheogo  wo  woso ltgos  tost les
# u wosttens wosbu le boy sly tostt bout bo bu tle wo ts ty lostytte t wos  wos wostt bn  go loe  losts wo twoslt bu  los g  ty tostent toy loe gay wos  tos  ty bu bhe gos wo  wo tuttwos gt styles
# u d t tayt dosbe le bny spy wostt buu  br py tle d  tt ly postotpe t woy  wod wostt an  ga bhe  pos t we  woy t bu  tos g  py wostey  toy loe gay wos  dus  tn tu thd gos wo  t  toetwos gt st lpy
# g d   dayt u  tu te tnn  pa t  tt thu  br py  le d  tt ty tost  tu t de   tod dostt en  ga t e  pos t de  wo  , bu  tes t  po te tey  tey toe gay tos  bos  t  tu t d got te  to the gos  tost tps
# g d   tan  to be le bnn  py bus t auu  bm te  le d  tt ty to to te   ta   tot tos t an  ga toe  pos t ty  wo  t bu  ton d  po te tes  tat toe gay tot  ba   to te tr  gat ta  to to  dot  to tt as
# g do  tos  totte le bss tpe los t auu  bm te  le d  tt er Io to te   to   tot wos t ast go toe  to  t ty  wos t bu  tat e  ty ta ten  tot toe gan tos  ba   totte b d got tot totto  wot  aa tttat
# g to  wost to bu le dot  te tot't auus bs ae  le do tt er Io t  teot go   tot wos't ast go toe  to  t te  wos t bu  tas e  ta ta len  lot toe gan tos  bas  lotbu b g got got to tue wot  austtlet
# g to  gont go bu le dos  pa dos't auus bo teo leito et e  Iost  te t to   to  won't ast ge toe  tus t by  wor , bu  tar e  to Ie len  ler toe  an tor  bas  lo bu b l got wo  wo to 'wot  aust,les
# g d   wan' go bu le dos  pe ton't aous bo peotleidh et er aost  pe t war  wot won't ast ge toe  pus t bys won s bur wan er Io Ie les  len toe gan dan  bas  lotlu b l got wot wh t d wos  tust,len
# g d   was' lo be le dos  pe bon't aous bn peo leidoget er Io t  pe t wo   wos wos t ast ge poe  pos t Iy  wor , bur wus e  wo Iu les  len toe  un don  bas  lotbe b t got wo  toetod wos  paseslen
# g d   wos' lo te le dos  p, Ion't dous bn peo le d  et er Io t  pe t wo   dns wos't dst ge t e  pos t Iyd wor , ber dus e  wo tu les  les toe gas dos  best lo be I l get wo  th to  dot  past,les
# g d   dos' lo te le dns  p, Ion't dyum bn teo le d get er Io t  pe t go   dss won't dst ge toe  tos t Iyd work, bur das es Ia tu lay  len tos gay das  Iest ln by I d get de  th tud wot  pase,len
# g d   das' lo b, le dss  p, Ion't dyum bn teotle doget er Io t  tect ga   dsd won't dst ge toem tos t tyd work, bur get e  to ta lay  len ths lay dast tast ln by I t get get th tud dot  tose,len
# g do  das' uo ba le dns  t, Ion't doum bp te tlecdoget er to t  lect go   esd won't dst go toem tostt t,d work, bur tot er tf te las  ler the lay datt tast ln by I t got got th toi wot  tose,len
# g d   day' uo t, le d s  t, dos't druc bstteotle t get er tf t   e t war  tsd won't dst go t em tot t tyd wonk, bur got e  tf te las  ler ton lay dant test lntby I l got got to toi wos  tosmtlps
# g do  day' go ba le dss  t, Ion't arom up ta tlertoget er tf t  lect wa l tpd won't ast go toem tostt t,d wo l, bur tot er tf te las  ler the lay dast tayt ln by I t got got th toi wott tott,lan
# g do  dayt lo buite d s  pe dos't drum bp teosle thget er tf t  le t wo   tpd won't dst go toem tos,t tyd worl, bus uother tf te lash les the gay dost tast ln by I l got got th tod wot  tosmtles
# g d   dayt ao buile d s  pa dos't drum bp teosle toget er Io c  lect wo   asd won't dss go them tos,s lyd worl, bus gother If we tash ler the gay dost tast un by I t got got th toe dos  tosmtlps
# g do  dayt ao buila d s  pa don't drum up teople toget er Io c  lect wo l asd won't dst ge toem tastt w,d worl, bus uuther tf we tay, ler the  ay dost tayt un bu I m gut get th toe dos  poek,een
# g do  way' ao build d s  pa don't drum un people toget er Io c  lect ward asd won't dst ge them tasit wnd work, but uuther If we lay  let the may jost tayt un bu I m get get th too dos  posk,een
# g wo  wayt ao build d s  p, don't doum up people toget er Io c llect wo k asd won't dst ge them tasis gnd work, but guther If we tay  let the  ay jott tast us by I m get get th too dos  posm,lds
# g wo  wayt to build d si p, don't arum up people toget er to c llect work asd won't ass ge t em paski gnd work, but guther If we tash let the may jost tast un by I m get get to too wos  posk,ees
# g wo  wayt to build dssiip, don't arom up people tagether Io c llemt work tsd don't ass gn toem pasti pnd work, but ghther tf weolash let the may jost tast up by I m get get to too wos  posk,len
# g wo  wayt to tuild dssiip, don't arom up teople together to c llemt wo d and don't assige toem pasti pnd work, but ghther tf weobas, let the may just tass up by I miget get to too dhs  tosk les
# g wo  wayt to build dssi t, don't arum up people together Io collemt wood lnd won't assign them tasti wnd work, but ghther If we las, let toe day jost tess up by I miget get to tho doti tolk lee
# g wo  wayt to busld dssiit, don't arum up paople together Io collect wood and won't assign them pasti wnd work, but rhther If we las, let the may jost pass up by I miget get tootho woci talkiles
# g wo  wayt to build dssiit, don't arum up paople together Io collect wo d and don't ass gn them tasti Ind work, but rhther If we las, let the may just tass up by I miget get th tho whci t,lkiees
# g wo  mayt to build dssi t, don't arum up peoplectogether Io collect wo d asd won't assige them tasti wnd work, but ghther If we las, let the day just pass up by I miget get to too dusi tolk,eee
# g wo  mayt ao build assiip, don't arum up people together to collect word and don't ass gn toem pasti wnd work, but rhther If we las, let the dan just pass up by I miget rot to too dhc  talkieee
# g wo  wayt to build a siip, don't arum up people together to collect wo d and won't ass gn the  pasti and work, but rhther tf we las, let the gay just pass up by I migut rot to too wu   palk,lee
# g wo  wayt to build d siip, don't drum up teople together to collect wo d and won't dssign them taskt and work, but rhther tf we lan, let the day just pass up by I might ret to too whci talktlee
# g wog mayt to build d siip, don't drum up people together Io collect wood and won't dss gn them tastt and work, but rhther tf we lay, let the day just pass us by I might rot to too muc  talk,lee
# g wug mayt to build d siit, don't drum up paople together to collect wo d and don't dss gn them taski and work, but rhther If we lay, let the day just pass us by I might rnt to too muci talkilee
# g wuu mayt to build a siip, don't arum up people together to collect word and don't ass gn them taski and work, but rhther If we lay, let the day just pass us by I might rnt to too muci talkilee
# g wau mayt to build a siip, don't arum up people together Io collect word and don't assign them taski and work, but rhther If we las, let the day just pass us by I might gnt to too much palkilee
# p wuu wayt to build a siip, don't arum up people together Io collect word and don't asshgn them taski and work, but gather If we las, let the day just pass us by I might get to too much palkiuee
# g wau wayt to build a siip, don't drum up people together Io collect wood and don't asshgn them taski and work, but gather If we lay, let the day just pass us by I might get to too wuch talkiuee
# g wau wayt to build a siip, don't drum up people together to collect wood and don't dsshgn them taskt and work, but gather If we lay, let the day just pass us by I might get to too wuch talkiue,
# g wau wayt to build a ship, don't drum up people together to collect wood and don't dsshgn them taskt and work, but gather If we lay, let the day just pass us by I might get to too wuch talkiuee
# g wou wayt to muild a ship, don't drum up people together to collect wood and don't dsshgn them taski and work, but gather If we lay, let the day just pass us by I might get to too wuch talkiuee
# g jou want to build a ship, don't drum up people together to collect wood and don't dsshgn them taski and work, but rather If we lay, let the day just pass us by I might ret th too wuch talkiuee
# g jou want to build a ship, don't drum up people together to collect wood and don't asshgn them taski and work, but rather If we lay, let the day just pass us by I might ret to too much talkiuee
# g jou mant to build a ship, don't arum up people together to collect wood and don't asshgn them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talkinee
# g jou want to build a ship, don't arum up people together to collect wood and don't asshgn them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talkine,
# g jou wayt to build a ship, don't drum up people together to collect wood and don't asshgn them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talkiuee
# g jou want to build a ship, don't drum up people together to collect wood and don't asshgn them tasis and work, but rather If we lay, let the day just pass us by I might get to too much talkinee
# g jou want to build a ship, don't arum up people together to collect wood and don't asshgn them tasis and work, but rather If we lay, let the day just pass us by I might get to too much talkinee
# g jou want to build a ship, don't drum up people together to collect wood and don't asshgn them tasis and work, but rather If we lay, le  the day just pass us by I might get to too much talkinee
# g jou want to build a ship, don't drum up people together to collect word and don't asshgn them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talkin'e
# g jou want to build a ship, don't arum up people together to collect wood and don't asshgn them tasks and wook, but rather If we lay, let the day just pass us by I might ght to too much talkin'e
# g jou want to build a ship, don't arum up people together to collect wood and don't asshgn them tasks and work, but rather If we lay, let the day just pass us by I might get th too much talkinae
# p jou want to build a ship, don't arum up people together to collect word and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talkin'e
# g jou want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but ratker If we lay, let the day just pass us by I might get to too much talkinah
# g jou want to build a ship, don't arum up people together to collect wood and don't assign them tasks and dork, but rather If we lay, let the day just pass us by I might get to too much talkinah
# g jou want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talkingu
# g jou want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talkingh
# g wou want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talkingh
# g wou want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talkingh
# g wou want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talkingh
# g jou want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talkingh
# g jou want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talkingh
# g mou want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g nou want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g nou want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't arum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather If we lay, let the day just pass us by I might get to too much talking.
