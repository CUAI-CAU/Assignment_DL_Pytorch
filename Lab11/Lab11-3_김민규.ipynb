# %%
import torch
import torch.optim as optim
import numpy as np

# %%
# Random seed to make results deterministic and reproducible

torch.manual_seed(0)

# %%
# 문장
sentence = ("if you want to build a ship, don't drum up people together to "
            "collect wood and don't assign them tasks and work, but rather "
            "teach them to long for the endless immensity of the sea.")

# %%
# make dictionary
# 이전에 만든 sentence로 집합(sentence 안에 들어있는 알파벳을 저장) 만들고 이걸로 딕셔너리 생성
char_set = list(set(sentence)) # 'r', 'f',...
char_dic = {c: i for i, c in enumerate(char_set)} # 'r' : 0, 'f' : 1...

# %%
# hyper parameters
# 학습에 사용할 변수들 생성
dic_size = len(char_dic)
hidden_size = len(char_dic)
sequence_length = 10  # Any arbitrary number
learning_rate = 0.1

# %%
# data setting
# 학습에 사용할 데이터를 생성
x_data = []
y_data = []

# 'abcdefg'있으면 'abc' -> 'bcd'와 같은 [x,y]데이터셋을 생성
for i in range(0, len(sentence) - sequence_length):
    x_str = sentence[i:i + sequence_length]
    y_str = sentence[i + 1: i + sequence_length + 1]
    print(i, x_str, '->', y_str)

    x_data.append([char_dic[c] for c in x_str])  # x str to index
    y_data.append([char_dic[c] for c in y_str])  # y str to index

x_one_hot = [np.eye(dic_size)[x] for x in x_data]
# Out:
# 0 if you wan -> f you want
# 1 f you want ->  you want
# 2  you want  -> you want t
# 3 you want t -> ou want to
# 4 ou want to -> u want to
# 5 u want to  ->  want to b
# 6  want to b -> want to bu
# 7 want to bu -> ant to bui
# 8 ant to bui -> nt to buil
# 9 nt to buil -> t to build
# 10 t to build ->  to build
# 11  to build  -> to build a
# 12 to build a -> o build a
# 13 o build a  ->  build a s
# 14  build a s -> build a sh
# 15 build a sh -> uild a shi
# 16 uild a shi -> ild a ship
# 17 ild a ship -> ld a ship,
# 18 ld a ship, -> d a ship,
# 19 d a ship,  ->  a ship, d
# 20  a ship, d -> a ship, do
# 21 a ship, do ->  ship, don
# 22  ship, don -> ship, don'
# 23 ship, don' -> hip, don't
# 24 hip, don't -> ip, don't
# 25 ip, don't  -> p, don't d
# 26 p, don't d -> , don't dr
# 27 , don't dr ->  don't dru
# 28  don't dru -> don't drum
# 29 don't drum -> on't drum
# 30 on't drum  -> n't drum u
# 31 n't drum u -> 't drum up
# 32 't drum up -> t drum up
# 33 t drum up  ->  drum up p
# 34  drum up p -> drum up pe
# 35 drum up pe -> rum up peo
# 36 rum up peo -> um up peop
# 37 um up peop -> m up peopl
# 38 m up peopl ->  up people
# 39  up people -> up people
# 40 up people  -> p people t
# 41 p people t ->  people to
# 42  people to -> people tog
# 43 people tog -> eople toge
# 44 eople toge -> ople toget
# 45 ople toget -> ple togeth
# 46 ple togeth -> le togethe
# 47 le togethe -> e together
# 48 e together ->  together
# 49  together  -> together t
# 50 together t -> ogether to
# 51 ogether to -> gether to
# 52 gether to  -> ether to c
# 53 ether to c -> ther to co
# 54 ther to co -> her to col
# 55 her to col -> er to coll
# 56 er to coll -> r to colle
# 57 r to colle ->  to collec
# 58  to collec -> to collect
# 59 to collect -> o collect
# 60 o collect  ->  collect w
# 61  collect w -> collect wo
# 62 collect wo -> ollect woo
# 63 ollect woo -> llect wood
# 64 llect wood -> lect wood
# 65 lect wood  -> ect wood a
# 66 ect wood a -> ct wood an
# 67 ct wood an -> t wood and
# 68 t wood and ->  wood and
# 69  wood and  -> wood and d
# 70 wood and d -> ood and do
# 71 ood and do -> od and don
# 72 od and don -> d and don'
# 73 d and don' ->  and don't
# 74  and don't -> and don't
# 75 and don't  -> nd don't a
# 76 nd don't a -> d don't as
# 77 d don't as ->  don't ass
# 78  don't ass -> don't assi
# 79 don't assi -> on't assig
# 80 on't assig -> n't assign
# 81 n't assign -> 't assign
# 82 't assign  -> t assign t
# 83 t assign t ->  assign th
# 84  assign th -> assign the
# 85 assign the -> ssign them
# 86 ssign them -> sign them
# 87 sign them  -> ign them t
# 88 ign them t -> gn them ta
# 89 gn them ta -> n them tas
# 90 n them tas ->  them task
# 91  them task -> them tasks
# 92 them tasks -> hem tasks
# 93 hem tasks  -> em tasks a
# 94 em tasks a -> m tasks an
# 95 m tasks an ->  tasks and
# 96  tasks and -> tasks and
# 97 tasks and  -> asks and w
# 98 asks and w -> sks and wo
# 99 sks and wo -> ks and wor
# 100 ks and wor -> s and work
# 101 s and work ->  and work,
# 102  and work, -> and work,
# 103 and work,  -> nd work, b
# 104 nd work, b -> d work, bu
# 105 d work, bu ->  work, but
# 106  work, but -> work, but
# 107 work, but  -> ork, but r
# 108 ork, but r -> rk, but ra
# 109 rk, but ra -> k, but rat
# 110 k, but rat -> , but rath
# 111 , but rath ->  but rathe
# 112  but rathe -> but rather
# 113 but rather -> ut rather
# 114 ut rather  -> t rather t
# 115 t rather t ->  rather te
# 116  rather te -> rather tea
# 117 rather tea -> ather teac
# 118 ather teac -> ther teach
# 119 ther teach -> her teach
# 120 her teach  -> er teach t
# 121 er teach t -> r teach th
# 122 r teach th ->  teach the
# 123  teach the -> teach them
# 124 teach them -> each them
# 125 each them  -> ach them t
# 126 ach them t -> ch them to
# 127 ch them to -> h them to
# 128 h them to  ->  them to l
# 129  them to l -> them to lo
# 130 them to lo -> hem to lon
# 131 hem to lon -> em to long
# 132 em to long -> m to long
# 133 m to long  ->  to long f
# 134  to long f -> to long fo
# 135 to long fo -> o long for
# 136 o long for ->  long for
# 137  long for  -> long for t
# 138 long for t -> ong for th
# 139 ong for th -> ng for the
# 140 ng for the -> g for the
# 141 g for the  ->  for the e
# 142  for the e -> for the en
# 143 for the en -> or the end
# 144 or the end -> r the endl
# 145 r the endl ->  the endle
# 146  the endle -> the endles
# 147 the endles -> he endless
# 148 he endless -> e endless
# 149 e endless  ->  endless i
# 150  endless i -> endless im
# 151 endless im -> ndless imm
# 152 ndless imm -> dless imme
# 153 dless imme -> less immen
# 154 less immen -> ess immens
# 155 ess immens -> ss immensi
# 156 ss immensi -> s immensit
# 157 s immensit ->  immensity
# 158  immensity -> immensity
# 159 immensity  -> mmensity o
# 160 mmensity o -> mensity of
# 161 mensity of -> ensity of
# 162 ensity of  -> nsity of t
# 163 nsity of t -> sity of th
# 164 sity of th -> ity of the
# 165 ity of the -> ty of the
# 166 ty of the  -> y of the s
# 167 y of the s ->  of the se
# 168  of the se -> of the sea
# 169 of the sea -> f the sea.

# %%
# transform as torch tensor variable
# 앞서 만든 데이터를 텐서로 생성
X = torch.FloatTensor(x_one_hot)
Y = torch.LongTensor(y_data)
# Out:
# <ipython-input-7-52579379b225>:2: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   X = torch.FloatTensor(x_one_hot)

# %%
# declare RNN + FC
# 네트워크 생성
class Net(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, layers):
        super(Net, self).__init__()
        self.rnn = torch.nn.RNN(input_dim, hidden_dim, num_layers=layers, batch_first=True)
        self.fc = torch.nn.Linear(hidden_dim, hidden_dim, bias=True)

    def forward(self, x):
        x, _status = self.rnn(x)
        x = self.fc(x)
        return x


net = Net(dic_size, hidden_size, 2)

# %%
# loss & optimizer setting
# 로스, 최적화 방식 선정
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), learning_rate)

# %%
# start training
# 학습 + 결과값 확인
for i in range(100):
    optimizer.zero_grad()
    outputs = net(X)
    loss = criterion(outputs.view(-1, dic_size), Y.view(-1))
    loss.backward()
    optimizer.step()

    results = outputs.argmax(dim=2)
    predict_str = ""
    for j, result in enumerate(results):
        # print(i, j, ''.join([char_set[t] for t in result]), loss.item())
        if j == 0:
            predict_str += ''.join([char_set[t] for t in result])
        else:
            predict_str += char_set[result[-1]]

    # 예측값 확인
    print(predict_str)
# Out:
# httt hhh'ht h hhhhhtht h  tththh tt thh h ttthtttht htttt  t hh hhthtth hthhh h hh tth hhhhht tt t' hh hh hhhththhht h tt   t h tth  t t hhhhhhh tht t  h  thh httth  tt hh t  hh h
#
#   tot tat  t   t                       t  t        t                 t                     t      t                        t t                                          t
# g.y'.tdmhk.kk.kkc.cc'ckkcc.i.c.k.ckc.c.kkkbcc.k.ykkkkkkkckcbybk.ck..ckk.kcbc.kkcbb.c.c.k.ccbykkck.ckkycc.kbkkc.c.k.ccc..ykkk'i.k.ck.cbbk.kk.cc..ckkckckc.c.c.kkccc.kkcamc..kcc.kkkc
# podhedhh dodo oh  eosoi   e dot  o   dodo oe   e po   eo  do  omoeoeo h doioe do  em    ieg ioeoto m   dp get t  o  oo  h odo oeo he  mh mh   ihi mh doh  e   t etoi i   ioto  io
# p do
# t cotototo to to to oototo  toto ooo ooto  o co ooo ooooaoto to ootoooo tooot totototo   ooooototo o to o to ot co  toto toto  t to toto to o to oaotooo  to   otoao t tot to ooo t
# toto tt  tototto to to tat  to ta to t to to to tto ta ta totto to tatottott  to ta ta ttatta tatatt tto tto ta to tto ta ttattt to totttto tatottt  tt ttt  tta tat to to to ta tt
# tee        to to  e e       to         to t      e        e  to      e        to                          to    to  e      t     to      t    to  e       e   e      e  t  t
# totonfwo..owont.    wotod..nwon'to..u.owot..n..o to tno notonw.n.o.. wo .ftn.ow...nhtn.owo to n to n  ton wonknowo...ow tnn.o.nwowo.noto tond wut..o..t..o.o  to  nn topto wonw.o.o
# toto t  t  toslo    tot  to tost  to t to lo    tt  t   n t tto      los  tos tost  to          lo    tos tos t to  tos  no  t   to t toslo t los to  t t lo  lo  n  lo lo to n   t
# tot  t  ta to lo    t t  t  to    t  t  o lo    tt          t o    a lo   to  to    t        t   o    to  lo    tot  o       t   to t  o lo t tos to    t  t   o  t   o  o th
# tot  d  td tos o  h d t     don  hth d  o  os  ottot  h n   t ot o d to   to  do  tht       h    o     nd do  t  ot ah  o    t   th n  o  otd tos to    d  t   o      o  o  h n
# tot ndtetd tos os etdnd     don tht nt to eon  otdot nh n  et on on  tos  dnd don tht s  o  o  hto    end do  s eo  to een  es h to n to  ond don to n  d et  do  nd  o eo  o n  n
# tntendtend tonbos etd d e e don tet ne doeeon  endon  henht n oneond ton  dnd dondtet s  os oeneton e dnd don s do  to eenht n eetoen to bond don toenend ens eo  nd do es eoene n
# tntendterd torbos etr d e e tondteto t toeeon  enterer erhton or end ton  tnd dondtetns bot oen tor i dnd don s do  tor ethton  etoen torbond bor toenend ens do  nd bo es boe e r
# totendtend to bo  eet d e d tondthto t toepon ient rhrherhtonbor'erd wo   tns tordthtnsiiht oer tonki d d to  s to  torhethton s toer to bord wor toerbnd dnsito  nd lhtes toene d
# ththoe ond wo boelo andhecd aon'thtooe totpom' emtonh hechth bo  en' ao   and aot'thtns lntpoem to 's and to hs aoehto hechthnchethec to bons wo hthectnd ans toe ns to po toemt r
# thths tond to bo ld a t  td aon'thtoo  to pon lonlh   hec th bo lems to   ans aonsthtnsiinslhem tonksidns do hs ao hah hec thncs thec to bon' ao  therlnd dnsilos ns ghths theclnr
# ththudtond to bo ld a d  ad aon'thtpod to po ltonlh  rher to lo lems to c and aon'thtnsig,tlhem ton'i dns ao  s ao  to hec to ls toem to lon' ao  toe lnd dnsilo  ns golps themlns
# thteudtond to boeld and  ud ton't tpud toepe llent r r er tonlo lems to c and aon't tps gntlhem tonk  dnd ao  d aot to  er tonch toer to bend ao  toertnd dnsitpo nd botpu thertnr
# ththugto g to bu td ant  ud tondt toum to penslent r rher th bo lers to c and tondt tns gn ther tonk  and aor d aot to her thnch ther to bend to  thertnd dnsitoe ns in pu thert rc
# ththusto g to bo td ant ipm don't toum tp penslemt r ther th to lers to c and tondt tnsi n then to ksiand aon d bot to he  thnch them to ben' to  the tnd dnsito  n' in p  the t r
# ththutto ' to boetd ant ipm aon't toum tp pe siemt r   em th bo lems to c and won't tnsi n them to ksiand ao  d bot to hem th chethem to ben' to  the tod ensitooen' tn po the t rc
# ththutto g to buttd ans ipm don't apum tp pe ste thr the  thsto lems to c and aon't ansign them to ksians aonkd bot fashe  thsch them to ben' wo  the tod dssiipmont tn ps the thrc
# thteutto g to buttd ans ipm don't aput ap pe s e threthe  th bo lems to s dnd don't ansign the  to ks ans dork, but fa he  thsch the  to bon' wo  the tnd dssiipy ns tn os the th c
# thteudtasd to budtd and ipd don't tput ap tesste torether totboilers totp and aon't tssign them tosks and donk, but fathem thscs the  tatben' wo  the tod dssiipyen' tn ou the tort
# th euttant to build andhip, don't toum ap pens e torethem thtco lecs totp and aon't tnsign them totks and donk, but aathem thnch them to bon' to  themtnd ess ioyen' tn ou the tont
# tn oustang to build anship, don't tour ap pensle t rether thtcoilecs tots dnd don't tnsign them totks and donk, but aather thscs them ta bon' to  thertnd dss ioyen' tn ou thertonl
# th ou'tang to luild a d ip, don't aoum ap pe sle torethem to lo lems to s and don't ansign lhem ta ki and don , but ra hem to  h them to bon' fo  toemtod ess iomens gn ou toe tonl
# tn puttand totcuild d ship, don't tput tptpesplentogether totdotlecs taos dnd don't ttsign lhep tatks and donk, but tather taocs ther tatcong tor therl d ess ipmon' tn ou therdogc
# tn oultong to luile a s ip, don't toum tp pe s e togeshem th lo lens toos dnd won't tnh gn lhem totks and donk, but toshem th ch them ta long to  themend ens irmens tn ou the eocc
# th ouetond to luile pns ip, don't aoum up pe s e toreshem to lo lens wo   dnd don't anh gn lhem toshi and don , buteua hem to ch them to bon' wo  themend esk iamens in ou themeocc
# ph ou'tang to luild a ship, don't aou  tp pe ple togesher tholoilecs toop dnd don't askign lhep tosks and dor , but rasher thoch ther to cong for themend esk ipmens ty ou themeocc
# phtpottasg torcuild asship, don't arut tp peotle toresher th coilecs tord dnd don't arsign thep totks and dor , but tasher thoch ther totcong for thertod ess ipmensity of thertogc
# phtoultant torbuild a ship, don't arum up pesple togeshem torboilecs forp dnd don't assign lhem tosks and dor , but rasher torch the  ta bon' for the end ess iomens ty of the eocc
# phtoultont to build a ship, don't arum up pe ple toceshem th bo lecs fors dnd don't assign lhem tasks and aor , dut rashem th ch them ta bon' for the tnd ess iomens ty ou the tocc
# pntoultant torbuild a ship, don't arum up pesple togesher th bo lecs word wnd don't assign them tonks and dork, but rather thnch ther to bon' forkthe tnd ess immensity ou the tocc
# pntouttant to build a ship, don't arum up pe dle together to bo lect tood wnd don't assign them totks and dork, but rather teoch ther ta bong forkthe tnd ess immensity ofkthe tocl
# pn ofttant to build a ship, don't arum up pe dle together to bo lecs wood wnd don't assign lhem tatks and dork, but rather to ch ther ta bong forktoe end ess immensity of the eocl
# pn ofttant to build a ship, don't arum up pe ple together to co lecs wood wnd won't assign lhe  tosks and wo k, but rather to ch the  ta bong fo kthe end ess immensity of the eocl
# pn ou tant to build a ship, don't arum up pe ple together te co lecs wood wnd won't assign lhem tosks and wor , but rather teoch ther to cong for the end ess immensity of the eocl
# pntouetant torluild a ship, don't arum up people together te co lect wood and won't assign ther totks and wor , but rather teoch them to bong for themend ess immensity ou themeocl
# pntouttant to build a ship, don't arum up pe ple together te lo lect wood and don't assign them tatks and dor , but uather teoch the  ta bong for the end ess immensity ou the eecl
# pntooetant to build a ship, don't arum up people together te lo lecs wood and don't assign them tatks and dor , but rather teoch the  ta long for the end ess immensity of the eegl
# pntooetant to luild a ship, don't arum up people together te co lecs wood and don't assign them totks and dor , but rather teoch the  to long for the end ess immensity of the eet
# pntou want to build a ship, don't arum up people together to co lect wood dnd don't dssign them totks and dork, but rather tooch the  to long for the end ess immensity of the eec
# pntou want to build a ship, don't drum up people together to bo lect wood wnd won't dssign them tosks and work, but rather tooch them to long for the end ess immensity of the eec
# pntou want to luild a ship, don't arum up people together to co lect wood wnd won't assign them tosks and work, but rather tooch the  to long for the end ess immensity of the eec
# pn ou want to build a ship, don't arum up pe ple together to co lect wood and won't assign them tosks and work, but rather tooch the  to bong for the end ess immensity of the eec
# pn ou want to build a ship, don't arum up people together to co lect wood and won't assign them tosks and work, but rather teoch them to bong for the end ess immensity of the eec
# pn ou want to build a ship, don't arum up people together te collect wood and won't assign them tosks and work, but rather teoch them to long for the end ess immensity of the eec
# pn ou want to luild a ship, don't arum up people together te collect wood dnd don't assign them tosks and dork, but rather teoch the  to long for the end ess immensity of the eec
# pn ou want to build a ship, don't drum up people together to collect wood dnd don't dssign them tosks and dork, but rather tooch them ta long for the end ess immensity of the eec
# pn ou want to build a ship, don't drum up people together te co lect wood dnd won't dssign them tasks and work, but rather teoch the  ta long for the end ess immensity of the eec
# pn ou want to build a ship, don't drum up people together te collect wood dnd won't dssign them tosks and dork, but rather teoch them to long for the end ess immensity of the eec
# pn ou want to build a ship, don't arum up people together te collect wood dnd don't assign them tasks and dork, but rather teoch the  to long for the endless immensity of the eec
# pn ru want to build a ship, don't arum up people together to collect wood dnd don't assign them tasks and dork, but rather teoch them to long for the endless immensity of the eec
# pn ou want to build a ship, don't arum up people together to collect wood and won't assign them tosks and dork, but rather tooch them to long for the endless immensity of the eec
# pn lu tant to build a ship, don't arum up people together te collect wood ant won't assign them tasss and dork, but rather teoch them ta cong for the endless immensity of the eec
# py ou wand to build a ship, don't drum up people together to bollectewood dnd don't dssign them tosks and dork, but rather tooch them to long for the endless immensity of the eeat
# pn ou want to luild a ship, don't drum up people together te collect wood and won't dssign thec tasks and work, but rather te ch the  wa  ong for the tnd ess immensity of the tu
# py ou want to build a ship, don't arum up people together te collect wood a d don't askign them tasks and aork, but rather teach the  to bong for thecend ess immensity of theceoa
# pn ou want to build a ship, don't drum up people together te bollecs wood wnd won't dssign ther tosks and work, but rather teoch them to bong for themendlessiimmensity of themeea
# pntou want to build a ship, don't drum uplpeople together te collect wood dnd don't dssign them totks and work, but rather teoch them to long for the endless immensity of the eeat
# pntou want to cuild a ship, don't arum up pe ple together te collect wood dnd don't assign them tasks and dork, but rather teach them to long for the endless immensity of the eeat
# pntou want to build a ship, don't arum up people together th collect wood and don't assign them tasks and dork, but rather teach them ta long for the endless immensity of the eeat
# pn ou want to build a ship, don't arum up people together te collect wood and don't assign them tosks and dork, but rather teach them to long for the endless immensity of the eeat
# pytou want to build a ship, don't arum up people together te collect wood wnd don't assign them tosks and dork, but rathem teach them to long for the endless immensity of the eeat
# pytwu want to build a ship, don't arum up people together te collect wood dnd don't assign them tosks and dork, but rather teach them to long for the endless immensity of the eeat
# pytou want to build a ship, don't arum up people together te collect wood and don't assign them tasks and dork, but rather teach them to long for the endless immensity of the eeat
# pytou want to build a ship, don't drum up people together to collect wood dnd don't dssign them tosks and dork, but rather teach them to long for the endless immensity of the eea
# pntlu want to build a ship, don't drum up people together te collect wood and won't dssign them tosks and work, but rather teach them to long for the endless immensity of the eet
# pntou want to build a ship, don't drum up people together te collect wood and won't dssign them tasks and work, but rather teach them ta long for the endless immensity of the eeat
# antou want to build a ship, don't drum up people together te collect wood and won't assign them tasks and work, but rather teach them ta lon' for the endless immensity of the eeat
# antou want to build a ship, don't arum up people together te collect wood and won't assign them tasks and work, but rather teach them ta loug for the endless immensity of the eeat
# pntou want to build a ship, don't arum up people together te collect wood and won't assign them tasks and work, but rather teach them ta long for the endless immensity of the eeat
# pntou want to build a ship, don't arum up people together te collect wood and won't assign them tasks and work, but rather teach them to long for the endless immensity of the eea
# pnlou want to build a ship, don't drum up people together te collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the eea
# pntou want to build a ship, don't drum up people together te collect wood and don't dssign them tasks and dork, but rather teach them ta long for the endless immensity of the eea
# pntou want to build a ship, don't drum up people together te collect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the eea
# pn ou want to build a ship, don't drum up people together te collect wood and won't dssign them tasks and work, but rather teach them ta long for the endless immensity of the eea
# tn ou want to build a ship, don't arum up people together te collect wood and don't assign them tasks and work, but rather teach them ta long for the endless immensity of the eea
# tntou want to build a ship, don't drum up people together te collect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the eeat
# tctou want to build a ship, don't drum up people together te collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the eeat
# tntou want to build a ship, don't drum up people together te collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the eeat
# tytou want to build a ship, don't arum up people together te collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the eea
# tntou want to build a ship, don't arum up people together te collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the eea
# tntou want to build a ship, don't drum up people together te collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the eeat
# t tou want to build a ship, don't drum up people together te collect wood and don't assign them tasks and work, but rather teach them ta long for the endless immensity of the eea
# p tou want to build a ship, don't drum up people together te collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the eea
# p tou want to build a ship, don't arum up people together te collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the eeat
# p tou want to build a ship, don't drum up people together te collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the eeat
# t tou want to build a ship, don't drum up people together te collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the eea
# t tou want to build a ship, don't arum up people together te collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the eea
# t sou want to build a ship, don't drum up people together te collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the eea
# t sou want to build a ship, don't drum up people together te collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the eeat
# t rou want to build a ship, don't arum up people together te collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the eeat
# t sou want to build a ship, don't drum up people together te collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the eeat
# t sou want to build a ship, don't drum up people together te collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the eea
